# %%
#crystal peptides

# %%
import numpy as np

#angles 

kk=len(tt2)
kkk=len(tt1)

mm = np.zeros(kk)
mm2 = np.zeros(kk)
mm3 = np.zeros(kk)

data44 =[data0,mm,mm2,data2,data3,mm3,data4,data5,data6]


result = []

for i in range (0,kk,1):
    for j in range (0,9,1):
        row=data44[j][i]
        result.append(row)
   
   
sublists = []
for i in range(0, len(result), 9):
    sublist = result[i:i+9]
    sublists.append(sublist)



data=np.array(sublists)

h=0
i=0
j=0

sub_matrices = []
for i in range(0, kk, 1):  
         for j in range(0, 1):  
            h=j
            sub_matrix = []
            for k in range(3):  
                #print('j')
                #print(j)
                row = data[i][j:j+3]
                j+=3 
                
                sub_matrix.append(row)
                
            sub_matrices.append(sub_matrix)


box_vectors = sub_matrices



box_vectors = np.array(box_vectors)

#print(box_vectors)
a=[]
b=[]
c=[]
a2=[]
b2=[]
c2=[]
a22=[]
b22=[]
c22=[]



 
# Calculate the box angles
for i in range(0, kk, 1):
    a = np.arccos(np.dot(box_vectors[i][0], box_vectors[i][1]) / (np.linalg.norm(box_vectors[i][0]) * np.linalg.norm(box_vectors[i][1]))) * 180 / np.pi
    c = np.arccos(np.dot(box_vectors[i][1], box_vectors[i][2]) / (np.linalg.norm(box_vectors[i][1]) * np.linalg.norm(box_vectors[i][2]))) * 180 / np.pi
    b = np.arccos(np.dot(box_vectors[i][0], box_vectors[i][2]) / (np.linalg.norm(box_vectors[i][0]) * np.linalg.norm(box_vectors[i][2]))) * 180 / np.pi
    a2.append(a)
    b2.append(b)
    c2.append(c)
    a22.append(a)
    b22.append(b)
    c22.append(c)



bf1=a22[0]
bf2=b22[0]
bf3=c22[0]

for i in range(0, kk, 1):
   a22[i]-=bf1


for i in range(0, kk, 1):
   b22[i]-= bf2

for i in range(0, kk, 1):
   c22[i]-= bf3



#################################################


mm = np.zeros(kkk)
mm2 = np.zeros(kkk)
mm3 = np.zeros(kkk)

data440 =[data10,mm,mm2,data12,data13,mm3,data14,data15,data16]


result0 = []

for i in range (0,kkk,1):
    for j in range (0,9,1):
        row0=data440[j][i]
        result0.append(row0)
   
   
sublists0 = []
for i in range(0, len(result0), 9):
    sublist0 = result0[i:i+9]
    sublists0.append(sublist0)



data1 =np.array(sublists0)


h1=0


sub_matrices1 = []
for i in range(0, kkk, 1): 
         for j in range(0, 1):  
            h=j
            sub_matrix1 = []
            for k in range(3):  
                row1 = data1[i][j:j+3]

                j+=3 
                
                sub_matrix1.append(row1)
                
            sub_matrices1.append(sub_matrix1)


box_vectors1 = sub_matrices1


box_vectors1 = np.array(box_vectors1)

#print(box_vectors)
a1=[]
b1=[]
c1=[]
a21=[]
b21=[]
c21=[]
a221=[]
b221=[]
c221=[]

 
# Calculate the box angles
for i in range(0, kkk, 1):
    a1 = np.arccos(np.dot(box_vectors1[i][0], box_vectors1[i][1]) / (np.linalg.norm(box_vectors1[i][0]) * np.linalg.norm(box_vectors1[i][1]))) * 180 / np.pi
    c1 = np.arccos(np.dot(box_vectors1[i][1], box_vectors1[i][2]) / (np.linalg.norm(box_vectors1[i][1]) * np.linalg.norm(box_vectors1[i][2]))) * 180 / np.pi
    b1 = np.arccos(np.dot(box_vectors1[i][0], box_vectors1[i][2]) / (np.linalg.norm(box_vectors1[i][0]) * np.linalg.norm(box_vectors1[i][2]))) * 180 / np.pi
    a21.append(a1)
    b21.append(b1)
    c21.append(c1)
    a221.append(a1)
    b221.append(b1)
    c221.append(c1)

# print(a221)
# print(b221)
# print(c221)


bf11=a221[0]
bf21=b221[0]
bf31=c221[0]


for i in range(0, kkk, 1):
   a221[i]-=bf11


for i in range(0, kkk, 1):
   b221[i]-=bf21

for i in range(0, kkk, 1):
   c221[i]-=bf31


#############
print('a')
mean1=sum(a221)/len(a221)
mean2=sum(b221)/len(b221)
mean3=sum(c221)/len(c221)


print("{:.1f}".format(mean1),',', "{:.1f}".format(mean2),',', "{:.1f}".format(mean3))

print('a100')
mean1=sum(a22)/len(a22)
mean2=sum(b22)/len(b22)
mean3=sum(c22)/len(c22)

print("{:.1f}".format(mean1),',', "{:.1f}".format(mean2),',', "{:.1f}".format(mean3))
######




for i in range (len(t1)):
    t1[i]/=1000

for i in range (len(t)):
    t[i]/=1000  



txam,a22xam,b22xam,c22xam,t1xam,a221xam,b221xam,c221xam=[],[],[],[],[],[],[],[]
txam=t
a22xam=a22
b22xam=b22
c22xam=c22
t1xam=t1
a221xam=a221
b221xam=b221
c221xam=c221

###########################################################

import numpy as np
import matplotlib.pyplot as plt
#"XX","YY","ZZ","YX","ZX","ZY"  
#xx 0 0,xy yy 0,zx zy zz
data0 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(1))
data2 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(4))
data3 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(2))
data4 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(5))
data5 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(6))
data6 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(3))

mm = np.zeros(51)
mm2 = np.zeros(51)
mm3 = np.zeros(51)

data44 =[data0,mm,mm2,data2,data3,mm3,data4,data5,data6]


result = []

for i in range (0,51,1):
    for j in range (0,9,1):
        row=data44[j][i]
        result.append(row)
   
   
sublists = []
for i in range(0, len(result), 9):
    sublist = result[i:i+9]
    sublists.append(sublist)

# print(sublists)


data=np.array(sublists)
# print(data)
h=0
i=0
j=0

sub_matrices = []
for i in range(0, 51, 1):  # iterate over every 3 rows
         for j in range(0, 1):  # iterate over every 3 columns
            h=j
            sub_matrix = []
            for k in range(3):  # extract the 3x3 sub-matrix
                #print('j')
                #print(j)
                row = data[i][j:j+3]
                #print('i')
                #print(i)
                #print('j2')
                #print(j)
                j+=3 
                
                sub_matrix.append(row)
                
            sub_matrices.append(sub_matrix)


box_vectors = sub_matrices



box_vectors = np.array(box_vectors)

#print(box_vectors)
a=[]
b=[]
c=[]
a2=[]
b2=[]
c2=[]
a22=[]
b22=[]
c22=[]




t = np.loadtxt('ang100.xvg',skiprows=29, usecols=(0))

 
# Calculate the box angles
for i in range(0, 51, 1):
    a = np.arccos(np.dot(box_vectors[i][0], box_vectors[i][1]) / (np.linalg.norm(box_vectors[i][0]) * np.linalg.norm(box_vectors[i][1]))) * 180 / np.pi
    c = np.arccos(np.dot(box_vectors[i][1], box_vectors[i][2]) / (np.linalg.norm(box_vectors[i][1]) * np.linalg.norm(box_vectors[i][2]))) * 180 / np.pi
    b = np.arccos(np.dot(box_vectors[i][0], box_vectors[i][2]) / (np.linalg.norm(box_vectors[i][0]) * np.linalg.norm(box_vectors[i][2]))) * 180 / np.pi
    a2.append(a)
    b2.append(b)
    c2.append(c)
    a22.append(a)
    b22.append(b)
    c22.append(c)


bf1=a22[0]
bf2=b22[0]
bf3=c22[0]

for i in range(0, 51, 1):
   a22[i]-=bf1


for i in range(0, 51, 1):
   b22[i]-= bf2

for i in range(0, 51, 1):
   c22[i]-= bf3



#################################################
data10 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(1))
data12 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(4))
data13 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(2))
data14 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(5))
data15 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(6))
data16 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(3))

mm = np.zeros(51)
mm2 = np.zeros(51)
mm3 = np.zeros(51)

data440 =[data10,mm,mm2,data12,data13,mm3,data14,data15,data16]


result0 = []

for i in range (0,51,1):
    for j in range (0,9,1):
        row0=data440[j][i]
        result0.append(row0)
   
   
sublists0 = []
for i in range(0, len(result0), 9):
    sublist0 = result0[i:i+9]
    sublists0.append(sublist0)



data1 =np.array(sublists0)


h1=0


sub_matrices1 = []
for i in range(0, 51, 1):  # iterate over every 3 rows
         for j in range(0, 1):  # iterate over every 3 columns
            h=j
            sub_matrix1 = []
            for k in range(3):  # extract the 3x3 sub-matrix
                #print('j')
                #print(j)
                row1 = data1[i][j:j+3]
                #print('i')
                #print(i)
                #print('j2')
                #print(j)
                j+=3 
                
                sub_matrix1.append(row1)
                
            sub_matrices1.append(sub_matrix1)


box_vectors1 = sub_matrices1


box_vectors1 = np.array(box_vectors1)

#print(box_vectors)
a1=[]
b1=[]
c1=[]
a21=[]
b21=[]
c21=[]
a221=[]
b221=[]
c221=[]
t1 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(0))

 
# Calculate the box angles
for i in range(0, 51, 1):
    a1 = np.arccos(np.dot(box_vectors1[i][0], box_vectors1[i][1]) / (np.linalg.norm(box_vectors1[i][0]) * np.linalg.norm(box_vectors1[i][1]))) * 180 / np.pi
    c1 = np.arccos(np.dot(box_vectors1[i][1], box_vectors1[i][2]) / (np.linalg.norm(box_vectors1[i][1]) * np.linalg.norm(box_vectors1[i][2]))) * 180 / np.pi
    b1 = np.arccos(np.dot(box_vectors1[i][0], box_vectors1[i][2]) / (np.linalg.norm(box_vectors1[i][0]) * np.linalg.norm(box_vectors1[i][2]))) * 180 / np.pi
    a21.append(a1)
    b21.append(b1)
    c21.append(c1)
    a221.append(a1)
    b221.append(b1)
    c221.append(c1)

# print(a221)
# print(b221)
# print(c221)


bf11=a221[0]
bf21=b221[0]
bf31=c221[0]


for i in range(0, 51, 1):
   a221[i]-=bf11


for i in range(0, 51, 1):
   b221[i]-=bf21

for i in range(0, 51, 1):
   c221[i]-=bf31


#############
print('a')
mean1=sum(a221)/len(a221)
mean2=sum(b221)/len(b221)
mean3=sum(c221)/len(c221)


print("{:.1f}".format(mean1),',', "{:.1f}".format(mean2),',', "{:.1f}".format(mean3))

print('a100')
mean1=sum(a22)/len(a22)
mean2=sum(b22)/len(b22)
mean3=sum(c22)/len(c22)

print("{:.1f}".format(mean1),',', "{:.1f}".format(mean2),',', "{:.1f}".format(mean3))
######

tyah,a22yah,b22yah,c22yah,t1yah,a221yah,b221yah,c221yah=[],[],[],[],[],[],[],[]
tyah=t
a22yah=a22
b22yah=b22
c22yah=c22
t1yah=t1
a221yah=a221
b221yah=b221
c221yah=c221
#############################################
import numpy as np
import matplotlib.pyplot as plt
#"XX","YY","ZZ","YX","ZX","ZY"  
#xx 0 0,xy yy 0,zx zy zz
data0 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(1))
data2 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(4))
data3 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(2))
data4 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(5))
data5 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(6))
data6 = np.loadtxt('ang100.xvg',skiprows=29, usecols=(3))

mm = np.zeros(51)
mm2 = np.zeros(51)
mm3 = np.zeros(51)

data44 =[data0,mm,mm2,data2,data3,mm3,data4,data5,data6]


result = []

for i in range (0,51,1):
    for j in range (0,9,1):
        row=data44[j][i]
        result.append(row)
   
   
sublists = []
for i in range(0, len(result), 9):
    sublist = result[i:i+9]
    sublists.append(sublist)

# print(sublists)


data=np.array(sublists)
# print(data)
h=0
i=0
j=0

sub_matrices = []
for i in range(0, 51, 1):  # iterate over every 3 rows
         for j in range(0, 1):  # iterate over every 3 columns
            h=j
            sub_matrix = []
            for k in range(3):  # extract the 3x3 sub-matrix
                row = data[i][j:j+3]
                j+=3 
                
                sub_matrix.append(row)
                
            sub_matrices.append(sub_matrix)


box_vectors = sub_matrices



box_vectors = np.array(box_vectors)

#print(box_vectors)
a=[]
b=[]
c=[]
a2=[]
b2=[]
c2=[]
a22=[]
b22=[]
c22=[]




t = np.loadtxt('ang100.xvg',skiprows=29, usecols=(0))
 
# Calculate the box angles
for i in range(0, 51, 1):
    a = np.arccos(np.dot(box_vectors[i][0], box_vectors[i][1]) / (np.linalg.norm(box_vectors[i][0]) * np.linalg.norm(box_vectors[i][1]))) * 180 / np.pi
    c = np.arccos(np.dot(box_vectors[i][1], box_vectors[i][2]) / (np.linalg.norm(box_vectors[i][1]) * np.linalg.norm(box_vectors[i][2]))) * 180 / np.pi
    b = np.arccos(np.dot(box_vectors[i][0], box_vectors[i][2]) / (np.linalg.norm(box_vectors[i][0]) * np.linalg.norm(box_vectors[i][2]))) * 180 / np.pi
    a2.append(a)
    b2.append(b)
    c2.append(c)
    a22.append(a)
    b22.append(b)
    c22.append(c)

# print(a22[0])
# print(b22[0])
# print(c22[0])

bf1=a22[0]
bf2=b22[0]
bf3=c22[0]

for i in range(0, 51, 1):
   a22[i]-=bf1


for i in range(0, 51, 1):
   b22[i]-= bf2

for i in range(0, 51, 1):
   c22[i]-= bf3



#################################################
data10 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(1))
data12 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(4))
data13 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(2))
data14 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(5))
data15 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(6))
data16 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(3))

mm = np.zeros(51)
mm2 = np.zeros(51)
mm3 = np.zeros(51)

data440 =[data10,mm,mm2,data12,data13,mm3,data14,data15,data16]


result0 = []

for i in range (0,51,1):
    for j in range (0,9,1):
        row0=data440[j][i]
        result0.append(row0)
   
   
sublists0 = []
for i in range(0, len(result0), 9):
    sublist0 = result0[i:i+9]
    sublists0.append(sublist0)



data1 =np.array(sublists0)


h1=0
#matrix = [...]  # your matrix with 9 rows and 5000 columns

sub_matrices1 = []
for i in range(0, 51, 1):  # iterate over every 3 rows
         for j in range(0, 1):  # iterate over every 3 columns
            h=j
            sub_matrix1 = []
            for k in range(3):  # extract the 3x3 sub-matrix
                #print('j')
                #print(j)
                row1 = data1[i][j:j+3]
                #print('i')
                #print(i)
                #print('j2')
                #print(j)
                j+=3 
                
                sub_matrix1.append(row1)
                
            sub_matrices1.append(sub_matrix1)


box_vectors1 = sub_matrices1


box_vectors1 = np.array(box_vectors1)

#print(box_vectors)
a1=[]
b1=[]
c1=[]
a21=[]
b21=[]
c21=[]
a221=[]
b221=[]
c221=[]
t1 = np.loadtxt('ang3.xvg',skiprows=29, usecols=(0))

 
# Calculate the box angles
for i in range(0, 51, 1):
    a1 = np.arccos(np.dot(box_vectors1[i][0], box_vectors1[i][1]) / (np.linalg.norm(box_vectors1[i][0]) * np.linalg.norm(box_vectors1[i][1]))) * 180 / np.pi
    c1 = np.arccos(np.dot(box_vectors1[i][1], box_vectors1[i][2]) / (np.linalg.norm(box_vectors1[i][1]) * np.linalg.norm(box_vectors1[i][2]))) * 180 / np.pi
    b1 = np.arccos(np.dot(box_vectors1[i][0], box_vectors1[i][2]) / (np.linalg.norm(box_vectors1[i][0]) * np.linalg.norm(box_vectors1[i][2]))) * 180 / np.pi
    a21.append(a1)
    b21.append(b1)
    c21.append(c1)
    a221.append(a1)
    b221.append(b1)
    c221.append(c1)

# print(a221)
# print(b221)
# print(c221)


bf11=a221[0]
bf21=b221[0]
bf31=c221[0]


for i in range(0, 51, 1):
   a221[i]-=bf11


for i in range(0, 51, 1):
   b221[i]-=bf21

for i in range(0, 51, 1):
   c221[i]-=bf31


#############
print('a')
mean1=sum(a221)/len(a221)
mean2=sum(b221)/len(b221)
mean3=sum(c221)/len(c221)


print("{:.1f}".format(mean1),',', "{:.1f}".format(mean2),',', "{:.1f}".format(mean3))

print('a100')
mean1=sum(a22)/len(a22)
mean2=sum(b22)/len(b22)
mean3=sum(c22)/len(c22)

print("{:.1f}".format(mean1),',', "{:.1f}".format(mean2),',', "{:.1f}".format(mean3))
######


tyas,a22yas,b22yas,c22yas,t1yas,a221yas,b221yas,c221yas=[],[],[],[],[],[],[],[]
tyas=t
a22yas=a22
b22yas=b22
c22yas=c22
t1yas=t1
a221yas=a221
b221yas=b221
c221yas=c221
###################################









#deviation 

x, y,b,c = [], [],[],[]
x1, y1,b1,c1 = [], [],[],[]
x3, y3,b3,c3 = [], [],[],[]
x4, y4,b4,c4 = [], [],[],[]
y0,b0,c0 = [], [],[]
y03,b03,c03 = [], [],[]
y10,b10,c10 = [], [],[]
y40,b40,c40 = [], [],[]


with open("ch-a.xvg") as f:
    for i in range(26):
        next(f)
    for line in f:
        cols = line.split()
        #next(cols)
        if len(cols) == 4:
            x.append(float(cols[0]))
            y.append(float(cols[1]))
            y0.append(float(cols[1]))
            b.append(float(cols[2]))
            b0.append(float(cols[2]))
            c.append(float(cols[3]))
            c0.append(float(cols[3]))
            
            
            
with open("ch3-a.xvg") as f:
    for i in range(26):
        next(f)
    for line in f:

        cols = line.split()
        #next(cols)
        if len(cols) == 4:
            x3.append(float(cols[0]))
            y3.append(float(cols[1]))
            y03.append(float(cols[1]))
            b3.append(float(cols[2]))
            c3.append(float(cols[3]))
            b03.append(float(cols[2]))
            c03.append(float(cols[3]))

            
            
with open("ch100-a.xvg") as f:
    for i in range(26):
        next(f)
    
    for line in f:

        cols = line.split()
        #next(cols)
        if len(cols) == 4:
            x1.append(float(cols[0]))
            y1.append(float(cols[1]))
            b1.append(float(cols[2]))
            c1.append(float(cols[3]))
            y10.append(float(cols[1]))
            b10.append(float(cols[2]))
            c10.append(float(cols[3]))
            
            
            

with open("a.xvg") as f:
    for i in range(26):
        next(f)
    
    for line in f:

        cols = line.split()
        #next(cols)
        if len(cols) == 4:
            x4.append(float(cols[0]))
            y4.append(float(cols[1]))
            b4.append(float(cols[2]))
            c4.append(float(cols[3]))
            y40.append(float(cols[1]))
            b40.append(float(cols[2]))
            c40.append(float(cols[3]))
            



    
    
for i in range(len(x)):
    y0[i] =((y[i]-y[1])/ y[1])   *100   
    
for i in range(len(x)):
    b0[i] =((b[i]-b[1])/ b[1])   *100    
    
    
for i in range(len(x)):
    c0[i] =((c[i]-c[1])/ c[1])   *100     
    

for i in range(len(x3)):
    y03[i] =((y3[i]-y[1])/ y[1])   *100   
    
for i in range(len(x3)):
    b03[i] =((b3[i]-b[1])/ b[1])   *100    
    
    
for i in range(len(x3)):
    c03[i] =((c3[i]-c[1])/ c[1])   *100      
    

    
    
    
for i in range(len(x1)):
    y10[i] =((y1[i]-y1[1])/ y1[1])   *100   
    
for i in range(len(x1)):
    b10[i] =((b1[i]-b1[1])/ b1[1])   *100    
    
    
for i in range(len(x1)):
    c10[i] =((c1[i]-c1[1])/ c1[1])   *100     
    

for i in range(len(x4)):
    y40[i] =((y4[i]-y1[1])/ y1[1])   *100   
    
for i in range(len(x4)):
    b40[i] =((b4[i]-b1[1])/ b1[1])   *100    
    
    
for i in range(len(x4)):
    c40[i] =((c4[i]-c1[1])/ c1[1])   *100      
    
#####################    
print('a')
h=y0+y03
mean=sum(h)/len(h)
h2=b0+b03
mean1=sum(h2)/len(h2)
h3=c0+c03
mean2=sum(h3)/len(h3)

print("{:.1f}".format(mean),',', "{:.1f}".format(mean1),',', "{:.1f}".format(mean2))

print('a100')
h=y10+y40
mean0=sum(h)/len(h)
h2=b10+b40
mean10=sum(h2)/len(h2)
h3=c10+c40
mean20=sum(h3)/len(h3)

print("{:.1f}".format(mean0),',', "{:.1f}".format(mean10),',', "{:.1f}".format(mean20))
#######################  
for i in range(len(x3)):
    x3[i] /= 1000   

for i in range(len(x)):
    x[i] /= 1000     

    
for i in range(len(x1)):
    x1[i] /= 1000   

for i in range(len(x4)):
    x4[i] /= 1000



tyah,a22yah,b22yah,c22yah,t1yah,a221yah,b221yah,c221yah=[],[],[],[],[],[],[],[]
tyah=x
a22yah=y0
b22yah=b0
c22yah=c0
a22yah3=y03
b22yah3=b03
c22yah3=c03
t1yah=x1
a221yah=y10
b221yah=b10
c221yah=c10
a221yah3=y40
b221yah3=b40
c221yah3=c40

tyah3=x3
t1yah3=x4



####################
import numpy as np
import matplotlib.pyplot as plt

x, y,b,c = [], [],[],[]
x1, y1,b1,c1 = [], [],[],[]
x3, y3,b3,c3 = [], [],[],[]
x4, y4,b4,c4 = [], [],[],[]
y0,b0,c0 = [], [],[]
y03,b03,c03 = [], [],[]
y10,b10,c10 = [], [],[]
y40,b40,c40 = [], [],[]


with open("a.xvg") as f:
    for i in range(26):
        next(f)
    for line in f:
        cols = line.split()
        #next(cols)
        if len(cols) == 4:
            x.append(float(cols[0]))
            y.append(float(cols[1]))
            y0.append(float(cols[1]))
            b.append(float(cols[2]))
            b0.append(float(cols[2]))
            c.append(float(cols[3]))
            c0.append(float(cols[3]))
            
            
# """"""''''''            
# with open("yes-ch3-a.xvg") as f:
#     for i in range(26):
#         next(f)
#     for line in f:

#         cols = line.split()
#         #next(cols)
#         if len(cols) == 4:
#             x3.append(float(cols[0]))
#             y3.append(float(cols[1]))
#             y03.append(float(cols[1]))
#             b3.append(float(cols[2]))
#             c3.append(float(cols[3]))
#             b03.append(float(cols[2]))
#             c03.append(float(cols[3]))

# """"""''''''            
            
with open("a.xvg") as f:
    for i in range(26):
        next(f)
    
    for line in f:

        cols = line.split()
        #next(cols)
        if len(cols) == 4:
            x1.append(float(cols[0]))
            y1.append(float(cols[1]))
            b1.append(float(cols[2]))
            c1.append(float(cols[3]))
            y10.append(float(cols[1]))
            b10.append(float(cols[2]))
            c10.append(float(cols[3]))
  
    
for i in range(len(x)):
    y0[i] =((y[i]-y[1])/ y[1])   *100   
    
for i in range(len(x)):
    b0[i] =((b[i]-b[1])/ b[1])   *100    
    
    
for i in range(len(x)):
    c0[i] =((c[i]-c[1])/ c[1])   *100     
    

for i in range(len(x3)):
    y03[i] =((y3[i]-y[1])/ y[1])   *100   
    
for i in range(len(x3)):
    b03[i] =((b3[i]-b[1])/ b[1])   *100    
    
    
for i in range(len(x3)):
    c03[i] =((c3[i]-c[1])/ c[1])   *100      
    

    
    
    
for i in range(len(x1)):
    y10[i] =((y1[i]-y1[1])/ y1[1])   *100   
    
for i in range(len(x1)):
    b10[i] =((b1[i]-b1[1])/ b1[1])   *100    
    
    
for i in range(len(x1)):
    c10[i] =((c1[i]-c1[1])/ c1[1])   *100     
    

for i in range(len(x4)):
    y40[i] =((y4[i]-y1[1])/ y1[1])   *100   
    
for i in range(len(x4)):
    b40[i] =((b4[i]-b1[1])/ b1[1])   *100    
    
    
for i in range(len(x4)):
    c40[i] =((c4[i]-c1[1])/ c1[1])   *100      
    
    
for i in range(len(x3)):
    x3[i] /= 1000   

for i in range(len(x)):
    x[i] /= 1000     

    
for i in range(len(x1)):
    x1[i] /= 1000   

for i in range(len(x4)):
    x4[i] /= 1000
    
#####################    
print('a')
h=y0+y03
mean=sum(h)/len(h)
h2=b0+b03
mean1=sum(h2)/len(h2)
h3=c0+c03
mean2=sum(h3)/len(h3)

print("{:.1f}".format(mean),',', "{:.1f}".format(mean1),',', "{:.1f}".format(mean2))

print('a100')
h=y10+y40
mean0=sum(h)/len(h)
h2=b10+b40
mean10=sum(h2)/len(h2)
h3=c10+c40
mean20=sum(h3)/len(h3)

print("{:.1f}".format(mean0),',', "{:.1f}".format(mean10),',', "{:.1f}".format(mean20))
#######################   



tyas,a22yas,b22yas,c22yas,t1yas,a221yas,b221yas,c221yas=[],[],[],[],[],[],[],[]
tyas=x
a22yas=y0
b22yas=b0
c22yas=c0
a22yas3=y03
b22yas3=b03
c22yas3=c03
t1yas=x1
a221yas=y10
b221yas=b10
c221yas=c10
a221yas3=y40
b221yas3=b40

tyam3=x3
t1yam3=x4
c221yas3=c40
################################
import numpy as np
import matplotlib.pyplot as plt

x, y,b,c = [], [],[],[]
x1, y1,b1,c1 = [], [],[],[]
x3, y3,b3,c3 = [], [],[],[]
x4, y4,b4,c4 = [], [],[],[]
y0,b0,c0 = [], [],[]
y03,b03,c03 = [], [],[]
y10,b10,c10 = [], [],[]
y40,b40,c40 = [], [],[]


with open("a.xvg") as f:
    for i in range(26):
        next(f)
    for line in f:
        cols = line.split()
        #next(cols)
        if len(cols) == 4:
            x.append(float(cols[0]))
            y.append(float(cols[1]))
            y0.append(float(cols[1]))
            b.append(float(cols[2]))
            b0.append(float(cols[2]))
            c.append(float(cols[3]))
            c0.append(float(cols[3]))
            
         
            
with open("a.xvg") as f:
    for i in range(26):
        next(f)
    
    for line in f:

        cols = line.split()
        #next(cols)
        if len(cols) == 4:
            x1.append(float(cols[0]))
            y1.append(float(cols[1]))
            b1.append(float(cols[2]))
            c1.append(float(cols[3]))
            y10.append(float(cols[1]))
            b10.append(float(cols[2]))
            c10.append(float(cols[3]))
            

  


    
    
    
    
    
for i in range(len(x)):
    y0[i] =((y[i]-y[1])/ y[1])   *100   
    
for i in range(len(x)):
    b0[i] =((b[i]-b[1])/ b[1])   *100    
    
    
for i in range(len(x)):
    c0[i] =((c[i]-c[1])/ c[1])   *100     
    

for i in range(len(x3)):
    y03[i] =((y3[i]-y[1])/ y[1])   *100   
    
for i in range(len(x3)):
    b03[i] =((b3[i]-b[1])/ b[1])   *100    
    
    
for i in range(len(x3)):
    c03[i] =((c3[i]-c[1])/ c[1])   *100      
    

    
    
    
for i in range(len(x1)):
    y10[i] =((y1[i]-y1[1])/ y1[1])   *100   
    
for i in range(len(x1)):
    b10[i] =((b1[i]-b1[1])/ b1[1])   *100    
    
    
for i in range(len(x1)):
    c10[i] =((c1[i]-c1[1])/ c1[1])   *100     
    

for i in range(len(x4)):
    y40[i] =((y4[i]-y1[1])/ y1[1])   *100   
    
for i in range(len(x4)):
    b40[i] =((b4[i]-b1[1])/ b1[1])   *100    
    
    
for i in range(len(x4)):
    c40[i] =((c4[i]-c1[1])/ c1[1])   *100      
    
    
for i in range(len(x3)):
    x3[i] /= 1000   

for i in range(len(x)):
    x[i] /= 1000     

    
for i in range(len(x1)):
    x1[i] /= 1000   

for i in range(len(x4)):
    x4[i] /= 1000
    
#####################    
print('a')
h=y0+y03
mean=sum(h)/len(h)
h2=b0+b03
mean1=sum(h2)/len(h2)
h3=c0+c03
mean2=sum(h3)/len(h3)

print("{:.1f}".format(mean),',', "{:.1f}".format(mean1),',', "{:.1f}".format(mean2))

print('a100')
h=y10+y40
mean0=sum(h)/len(h)
h2=b10+b40
mean10=sum(h2)/len(h2)
h3=c10+c40
mean20=sum(h3)/len(h3)

print("{:.1f}".format(mean0),',', "{:.1f}".format(mean10),',', "{:.1f}".format(mean20))
#######################   
    
    
    
plt.rcParams['font.size'] = '16'            
fig = plt.figure(figsize=(5,3))
ax1 = fig.add_subplot(111)
#ax1.set_title("HC-131K")    
ax1.set_xlabel('Time (ns)')
ax1.set_ylabel('% deviation')
ax1.plot(x,y0, c='purple', label='NNQQ1-a/298K')
ax1.plot(x,b0, c='orange', label='NNQQ1-b/298K')
ax1.plot(x,c0, c='orangered', label='NNQQ1-c/298K')
ax1.plot(x3,y03, c='purple')
ax1.plot(x3,b03, c='orange')
ax1.plot(x3,c03, c='orangered')


tyas,a22yas,b22yas,c22yas,t1yas,a221yas,b221yas,c221yas=[],[],[],[],[],[],[],[]
tyas=x
a22yas=y0
b22yas=b0
c22yas=c0
a22yas3=y03
b22yas3=b03
c22yas3=c03
t1yas=x1
a221yas=y10
b221yas=b10
c221yas=c10
a221yas3=y40
b221yas3=b40

tyam3=x3
t1yam3=x4
c221yas3=c40

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.size'] = '14'            
#fig = plt.figure(figsize=(5,3))
#fig, (ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9) = plt.subplots(3, 3, figsize=(5,3))
fig, ax = plt.subplots(6, 3, figsize=(10,14))





ax[0,0].plot(tyam,a22yam,'--', c='blue',  linewidth=2)
ax[0,0].plot(tyam,b22yam,'--', c='royalblue', linewidth=2)
ax[0,0].plot(tyam,c22yam,'--', c='cyan', linewidth=2)
ax[0,0].plot(t1yam,a221yam, c='purple',  linewidth=2)
ax[0,0].plot(t1yam,b221yam, c='orange',  linewidth=2)
ax[0,0].plot(t1yam,c221yam, c='orangered', linewidth=2)

ax[0,1].plot(tyah,a22yah,'--', c='blue',  linewidth=2)
ax[0,1].plot(tyah,b22yah,'--', c='royalblue', linewidth=2)
ax[0,1].plot(tyah,c22yah,'--', c='cyan', linewidth=2)
ax[0,1].plot(t1yah,a221yah, c='purple',  linewidth=2)
ax[0,1].plot(t1yah,b221yah, c='orange',  linewidth=2)
ax[0,1].plot(t1yah,c221yah, c='orangered', linewidth=2)

ax[0,2].plot(tyas,a22yas,'--', c='blue',  linewidth=2)
ax[0,2].plot(tyas,b22yas,'--', c='royalblue', linewidth=2)
ax[0,2].plot(tyas,c22yas,'--', c='cyan', linewidth=2)
ax[0,2].plot(t1yas,a221yas, c='purple',  linewidth=2)
ax[0,2].plot(t1yas,b221yas, c='orange',  linewidth=2)
ax[0,2].plot(t1yas,c221yas, c='orangered', linewidth=2)

ax[1,0].plot(tpam,a22pam,'--', c='blue',  linewidth=2)
ax[1,0].plot(tpam,b22pam,'--', c='royalblue', linewidth=2)
ax[1,0].plot(tpam,c22pam,'--', c='cyan', linewidth=2)
ax[1,0].plot(t1pam,a221pam, c='purple',  linewidth=2)
ax[1,0].plot(t1pam,b221pam, c='orange',  linewidth=2)
ax[1,0].plot(t1pam,c221pam, c='orangered', linewidth=2)

ax[1,1].plot(tpah,a22pah,'--', c='blue',  linewidth=2)
ax[1,1].plot(tpah,b22pah,'--', c='royalblue', linewidth=2)
ax[1,1].plot(tpah,c22pah,'--', c='cyan', linewidth=2)
ax[1,1].plot(t1pam,a221pam, c='purple',  linewidth=2)
ax[1,1].plot(t1pam,b221pam, c='orange',  linewidth=2)
ax[1,1].plot(t1pam,c221pam, c='orangered', linewidth=2)

ax[1,2].plot(tpas,a22pas,'--', c='blue',  linewidth=2)
ax[1,2].plot(tpas,b22pas,'--', c='royalblue', linewidth=2)
ax[1,2].plot(tpas,c22pas,'--', c='cyan', linewidth=2)
ax[1,2].plot(t1pas,a221pas, c='purple',  linewidth=2)
ax[1,2].plot(t1pas,b221pas, c='orange',  linewidth=2)
ax[1,2].plot(t1pas,c221pas, c='orangered', linewidth=2)

ax[2,0].plot(tnam,a22nam,'--', c='blue',  linewidth=2)
ax[2,0].plot(tnam,b22nam,'--', c='royalblue', linewidth=2)
ax[2,0].plot(tnam,c22nam,'--', c='cyan', linewidth=2)
ax[2,0].plot(t1nam,a221nam, c='purple',  linewidth=2)
ax[2,0].plot(t1nam,b221nam, c='orange',  linewidth=2)
ax[2,0].plot(t1nam,c221nam, c='orangered', linewidth=2)

ax[2,1].plot(tnah,a22nah,'--', c='blue',  linewidth=2,label="alpha-cryo temperature")
ax[2,1].plot(tnah,b22nah,'--', c='royalblue', linewidth=2,label='beta-cryo temperature')
ax[2,1].plot(tnah,c22nah,'--', c='cyan', linewidth=2,label='gama-cryo temperature')
ax[2,1].plot(t1nah,a221nah, c='purple',  linewidth=2)
ax[2,1].plot(t1nah,b221nah, c='orange',  linewidth=2)
ax[2,1].plot(t1nah,c221nah, c='orangered', linewidth=2)

ax[2,2].plot(tnas,a22nas,'--', c='blue',  linewidth=2)
ax[2,2].plot(tnas,b22nas,'--', c='royalblue', linewidth=2)
ax[2,2].plot(tnas,c22nas,'--', c='cyan', linewidth=2)
ax[2,2].plot(t1nas,a221nas, c='purple',  linewidth=2)
ax[2,2].plot(t1nas,b221nas, c='orange',  linewidth=2)
ax[2,2].plot(t1nas,c221nas, c='orangered', linewidth=2)



ax[3,0].plot(txam,a22xam,'--', c='blue',  linewidth=2)
ax[3,0].plot(txam,b22xam,'--', c='royalblue', linewidth=2)
ax[3,0].plot(txam,c22xam,'--', c='cyan', linewidth=2)
ax[3,0].plot(t1xam,a221xam, c='purple',  linewidth=2)
ax[3,0].plot(t1xam,b221xam, c='orange',  linewidth=2)
ax[3,0].plot(t1xam,c221xam, c='orangered', linewidth=2)

ax[3,1].plot(txah,a22xah,'--', c='blue',  linewidth=2)
ax[3,1].plot(txah,b22xah,'--', c='royalblue', linewidth=2)
ax[3,1].plot(txah,c22xah,'--', c='cyan', linewidth=2)
ax[3,1].plot(t1xah,a221xah, c='purple',  linewidth=2,label='alpha-room temperature')
ax[3,1].plot(t1xah,b221xah, c='orange',  linewidth=2,label='beta-room temperature')
ax[3,1].plot(t1xah,c221xah, c='orangered', linewidth=2,label='gama-room temperature')

ax[3,2].plot(txas,a22xas,'--', c='blue',  linewidth=2)
ax[3,2].plot(txas,b22xas,'--', c='royalblue', linewidth=2)
ax[3,2].plot(txas,c22xas,'--', c='cyan', linewidth=2)
ax[3,2].plot(t1xas,a221xas, c='purple',  linewidth=2)
ax[3,2].plot(t1xas,b221xas, c='orange',  linewidth=2)
ax[3,2].plot(t1xas,c221xas, c='orangered', linewidth=2)


ax[4,0].plot(tkam,a22kam,'--', c='blue',  linewidth=2)
ax[4,0].plot(tkam,b22kam,'--', c='royalblue', linewidth=2)
ax[4,0].plot(tkam,c22kam,'--', c='cyan', linewidth=2)
ax[4,0].plot(t1kam,a221kam, c='purple',  linewidth=2)
ax[4,0].plot(t1kam,b221kam, c='orange',  linewidth=2)
ax[4,0].plot(t1kam,c221kam, c='orangered', linewidth=2)

ax[4,1].plot(tkah,a22kah,'--', c='blue',  linewidth=2)
ax[4,1].plot(tkah,b22kah,'--', c='royalblue', linewidth=2)
ax[4,1].plot(tkah,c22kah,'--', c='cyan', linewidth=2)
ax[4,1].plot(t1kah,a221kah, c='purple',  linewidth=2)
ax[4,1].plot(t1kah,b221kah, c='orange',  linewidth=2)
ax[4,1].plot(t1kah,c221kah, c='orangered', linewidth=2)

ax[4,2].plot(tkas,a22kas,'--', c='blue',  linewidth=2)
ax[4,2].plot(tkas,b22kas,'--', c='royalblue', linewidth=2)
ax[4,2].plot(tkas,c22kas,'--', c='cyan', linewidth=2)
ax[4,2].plot(t1kas,a221kas, c='purple',  linewidth=2)
ax[4,2].plot(t1kas,b221kas, c='orange',  linewidth=2)
ax[4,2].plot(t1kas,c221kas, c='orangered', linewidth=2)


ax[5,0].plot(tnaam,a22naam,'--', c='blue',  linewidth=2)
ax[5,0].plot(tnaam,b22naam,'--', c='royalblue', linewidth=2)
ax[5,0].plot(tnaam,c22naam,'--', c='cyan', linewidth=2)
ax[5,0].plot(t1naam,a221naam, c='purple',  linewidth=2)
ax[5,0].plot(t1naam,b221naam, c='orange',  linewidth=2)
ax[5,0].plot(t1naam,c221naam, c='orangered', linewidth=2)

ax[5,1].plot(tnaah,a22naah,'--', c='blue',  linewidth=2)
ax[5,1].plot(tnaah,b22naah,'--', c='royalblue', linewidth=2)
ax[5,1].plot(tnaah,c22naah,'--', c='cyan', linewidth=2)
ax[5,1].plot(t1naah,a221naah, c='purple',  linewidth=2)
ax[5,1].plot(t1naah,b221naah, c='orange',  linewidth=2)
ax[5,1].plot(t1naah,c221naah, c='orangered', linewidth=2)

ax[5,2].plot(tnaas,a22naas,'--', c='blue',  linewidth=2)
ax[5,2].plot(tnaas,b22naas,'--', c='royalblue', linewidth=2)
ax[5,2].plot(tnaas,c22naas,'--', c='cyan', linewidth=2)
ax[5,2].plot(t1naas,a221naas, c='purple',  linewidth=2)
ax[5,2].plot(t1naas,b221naas, c='orange',  linewidth=2)
ax[5,2].plot(t1naas,c221naas, c='orangered', linewidth=2)



ax[0,2].set_ylim([-5, 1.5])
ax[0,1].set_ylim([-5, 1.5])
ax[0,0].set_ylim([-5, 1.5])
ax[1,2].set_ylim([-5, 1.5])
ax[1,1].set_ylim([-5, 1.5])
ax[1,0].set_ylim([-5, 1.5])
ax[2,2].set_ylim([-5, 1.5])
ax[2,1].set_ylim([-5, 1.5])
ax[2,0].set_ylim([-5, 1.5])
ax[3,2].set_ylim([-5, 1.5])
ax[3,1].set_ylim([-5, 1.5])
ax[3,0].set_ylim([-5, 1.5])
ax[4,2].set_ylim([-5, 1.5])
ax[4,1].set_ylim([-5, 1.5])
ax[4,0].set_ylim([-5, 1.5])
ax[5,2].set_ylim([-5, 1.5])
ax[5,1].set_ylim([-5, 1.5])
ax[5,0].set_ylim([-5, 1.5])

ax[0,1].get_yaxis().set_visible(False)
ax[0,2].get_yaxis().set_visible(False)
ax[1,1].get_yaxis().set_visible(False)
ax[1,2].get_yaxis().set_visible(False)
ax[2,1].get_yaxis().set_visible(False)
ax[2,2].get_yaxis().set_visible(False)
ax[3,1].get_yaxis().set_visible(False)
ax[3,2].get_yaxis().set_visible(False)
ax[4,1].get_yaxis().set_visible(False)
ax[4,2].get_yaxis().set_visible(False)
ax[5,1].get_yaxis().set_visible(False)
ax[5,2].get_yaxis().set_visible(False)

ax[5,1].set_xlabel('Time (ns)')
ax[2,0].set_ylabel('$\Delta$Angels ($\degree$)')

leg=ax[2,1].legend(prop={"size":10})
leg2=ax[3,1].legend(prop={"size":10})

ax[0,0].text(20, 2, 'AMBER19SB')
ax[0,1].text(20, 2, 'CHARMM36m')
ax[0,2].text(20, 2, 'OPLS-AA/M')

ax[0,2].text(120, -1.9, 'NNQQNY', rotation='90')
ax[1,2].text(120, -1.9, 'GNNQQNY', rotation='90')
ax[2,2].text(130, -1.9, 'NNQQ (1)', rotation='90')
ax[3,2].text(260, -1.9, 'NNQQ (2)', rotation='90')
ax[4,2].text(120, -2.4, 'MVGGVV (1)', rotation='90')
ax[5,2].text(120, -2.4, 'MVGGVV (2)', rotation='90')

plt.subplots_adjust(wspace=0)
plt.savefig('angles1.pdf', dpi=100, bbox_inches='tight')

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.size'] = '14'            
#fig = plt.figure(figsize=(5,3))
#fig, (ax1,ax2,ax3,ax4,ax5,ax6,ax7,ax8,ax9) = plt.subplots(3, 3, figsize=(5,3))
fig, ax = plt.subplots(6, 3, figsize=(10,14))




ax[0,0].plot(tn9am,a22n9am,'--', c='blue',  linewidth=2)
ax[0,0].plot(tn9am,b22n9am,'--', c='royalblue', linewidth=2)
ax[0,0].plot(tn9am,c22n9am,'--', c='cyan', linewidth=2)
ax[0,0].plot(t1n9am,a221n9am, c='purple',  linewidth=2)
ax[0,0].plot(t1n9am,b221n9am, c='orange',  linewidth=2)
ax[0,0].plot(t1n9am,c221n9am, c='orangered', linewidth=2)

ax[0,1].plot(tn9ah,a22n9ah,'--', c='blue',  linewidth=2)
ax[0,1].plot(tn9ah,b22n9ah,'--', c='royalblue', linewidth=2)
ax[0,1].plot(tn9ah,c22n9ah,'--', c='cyan', linewidth=2)
ax[0,1].plot(t1n9ah,a221n9ah, c='purple',  linewidth=2)
ax[0,1].plot(t1n9ah,b221n9ah, c='orange',  linewidth=2)
ax[0,1].plot(t1n9ah,c221n9ah, c='orangered', linewidth=2)

ax[0,2].plot(tn9as,a22n9as,'--', c='blue',  linewidth=2)
ax[0,2].plot(tn9as,b22n9as,'--', c='royalblue', linewidth=2)
ax[0,2].plot(tn9as,c22n9as,'--', c='cyan', linewidth=2)
ax[0,2].plot(t1n9as,a221n9as, c='purple',  linewidth=2)
ax[0,2].plot(t1n9as,b221n9as, c='orange',  linewidth=2)
ax[0,2].plot(t1n9as,c221n9as, c='orangered', linewidth=2)

ax[1,0].plot(tvam,a22vam, c='blue',  linewidth=2)
ax[1,0].plot(tvam,b22vam, c='royalblue', linewidth=2)
ax[1,0].plot(tvam,c22vam, c='cyan', linewidth=2)
ax[1,0].plot(t1vam,a221vam, c='purple',  linewidth=2)
ax[1,0].plot(t1vam,b221vam, c='orange',  linewidth=2)
ax[1,0].plot(t1vam,c221vam, c='orangered', linewidth=2)

ax[1,1].plot(tvah,a22vah, c='blue',  linewidth=2)
ax[1,1].plot(tvah,b22vah, c='royalblue', linewidth=2)
ax[1,1].plot(tvah,c22vah, c='cyan', linewidth=2)
ax[1,1].plot(t1vah,a221vah, c='purple',  linewidth=2)
ax[1,1].plot(t1vah,b221vah, c='orange',  linewidth=2)
ax[1,1].plot(t1vah,c221vah, c='orangered', linewidth=2)

ax[1,2].plot(tvas,a22vas, c='blue',  linewidth=2)
ax[1,2].plot(tvas,b22vas, c='royalblue', linewidth=2)
ax[1,2].plot(tvas,c22vas, c='cyan', linewidth=2)
ax[1,2].plot(t1vas,a221vas, c='purple',  linewidth=2)
ax[1,2].plot(t1vas,b221vas, c='orange',  linewidth=2)
ax[1,2].plot(t1vas,c221vas, c='orangered', linewidth=2)

ax[2,0].plot(t8am,a228am,'--', c='blue',  linewidth=2)
ax[2,0].plot(t8am,b228am,'--', c='royalblue', linewidth=2)
ax[2,0].plot(t8am,c228am,'--', c='cyan', linewidth=2)
ax[2,0].plot(t18am,a2218am, c='purple',  linewidth=2)
ax[2,0].plot(t18am,b2218am, c='orange',  linewidth=2)
ax[2,0].plot(t18am,c2218am, c='orangered', linewidth=2)

ax[2,1].plot(t8ah,a228ah,'--', c='blue',  linewidth=2,label="alpha-cryo temperature")
ax[2,1].plot(t8ah,b228ah,'--', c='royalblue', linewidth=2,label='beta-cryo temperature')
ax[2,1].plot(t8ah,c228ah,'--', c='cyan', linewidth=2,label='gama-cryo temperature')
ax[2,1].plot(t18ah,a2218ah, c='purple',  linewidth=2)
ax[2,1].plot(t18ah,b2218ah, c='orange',  linewidth=2)
ax[2,1].plot(t18ah,c2218ah, c='orangered', linewidth=2)

ax[2,2].plot(t8as,a228as,'--', c='blue',  linewidth=2)
ax[2,2].plot(t8as,b228as,'--', c='royalblue', linewidth=2)
ax[2,2].plot(t8as,c228as,'--', c='cyan', linewidth=2)
ax[2,2].plot(t18as,a2218as, c='purple',  linewidth=2)
ax[2,2].plot(t18as,b2218as, c='orange',  linewidth=2)
ax[2,2].plot(t18as,c2218as, c='orangered', linewidth=2)

ax[3,0].plot(tqam,a22qam,'--', c='blue',  linewidth=2)
ax[3,0].plot(tqam,b22qam,'--', c='royalblue', linewidth=2)
ax[3,0].plot(tqam,c22qam,'--', c='cyan', linewidth=2)
ax[3,0].plot(t1qam,a221qam, c='purple',  linewidth=2)
ax[3,0].plot(t1qam,b221qam, c='orange',  linewidth=2)
ax[3,0].plot(t1qam,c221qam, c='orangered', linewidth=2)

ax[3,1].plot(tqah,a22qah,'--', c='blue',  linewidth=2)
ax[3,1].plot(tqah,b22qah,'--', c='royalblue', linewidth=2)
ax[3,1].plot(tqah,c22qah,'--', c='cyan', linewidth=2)
ax[3,1].plot(t1qah,a221qah, c='purple',  linewidth=2,label='alpha-room temperature')
ax[3,1].plot(t1qah,b221qah, c='orange',  linewidth=2,label='beta-room temperature')
ax[3,1].plot(t1qah,c221qah, c='orangered', linewidth=2,label='gama-room temperature')

ax[3,2].plot(tqas,a22qas,'--', c='blue',  linewidth=2)
ax[3,2].plot(tqas,b22qas,'--', c='royalblue', linewidth=2)
ax[3,2].plot(tqas,c22qas,'--', c='cyan', linewidth=2)
ax[3,2].plot(t1qas,a221qas, c='purple',  linewidth=2)
ax[3,2].plot(t1qas,b221qas, c='orange',  linewidth=2)
ax[3,2].plot(t1qas,c221qas, c='orangered', linewidth=2)


ax[4,0].plot(tgam,a22gam,'--', c='blue',  linewidth=2)
ax[4,0].plot(tgam,b22gam,'--', c='royalblue', linewidth=2)
ax[4,0].plot(tgam,c22gam,'--', c='cyan', linewidth=2)
ax[4,0].plot(t1gam,a221gam, c='purple',  linewidth=2)
ax[4,0].plot(t1gam,b221gam, c='orange',  linewidth=2)
ax[4,0].plot(t1gam,c221gam, c='orangered', linewidth=2)

ax[4,1].plot(tgah,a22gah,'--', c='blue',  linewidth=2)
ax[4,1].plot(tgah,b22gah,'--', c='royalblue', linewidth=2)
ax[4,1].plot(tgah,c22gah,'--', c='cyan', linewidth=2)
ax[4,1].plot(t1gah,a221gah, c='purple',  linewidth=2)
ax[4,1].plot(t1gah,b221gah, c='orange',  linewidth=2)
ax[4,1].plot(t1gah,c221gah, c='orangered', linewidth=2)

ax[4,2].plot(tgas,a22gas,'--', c='blue',  linewidth=2)
ax[4,2].plot(tgas,b22gas,'--', c='royalblue', linewidth=2)
ax[4,2].plot(tgas,c22gas,'--', c='cyan', linewidth=2)
ax[4,2].plot(t1gas,a221gas, c='purple',  linewidth=2)
ax[4,2].plot(t1gas,b221gas, c='orange',  linewidth=2)
ax[4,2].plot(t1gas,c221gas, c='orangered', linewidth=2)

ax[5,0].plot(tfam,a22fam,'--', c='blue',  linewidth=2)
ax[5,0].plot(tfam,b22fam,'--', c='royalblue', linewidth=2)
ax[5,0].plot(tfam,c22fam,'--', c='cyan', linewidth=2)
ax[5,0].plot(t1fam,a221fam, c='purple',  linewidth=2)
ax[5,0].plot(t1fam,b221fam, c='orange',  linewidth=2)
ax[5,0].plot(t1fam,c221fam, c='orangered', linewidth=2)

ax[5,1].plot(tfah,a22fah,'--', c='blue',  linewidth=2)
ax[5,1].plot(tfah,b22fah,'--', c='royalblue', linewidth=2)
ax[5,1].plot(tfah,c22fah,'--', c='cyan', linewidth=2)
ax[5,1].plot(t1fah,a221fah, c='purple',  linewidth=2)
ax[5,1].plot(t1fah,b221fah, c='orange',  linewidth=2)
ax[5,1].plot(t1fah,c221fah, c='orangered', linewidth=2)

ax[5,2].plot(tfas,a22fas,'--', c='blue',  linewidth=2)
ax[5,2].plot(tfas,b22fas,'--', c='royalblue', linewidth=2)
ax[5,2].plot(tfas,c22fas,'--', c='cyan', linewidth=2)
ax[5,2].plot(t1fas,a221fas, c='purple',  linewidth=2)
ax[5,2].plot(t1fas,b221fas, c='orange',  linewidth=2)
ax[5,2].plot(t1fas,c221fas, c='orangered', linewidth=2)





ax[0,2].set_ylim([-5, 1.5])
ax[0,1].set_ylim([-5, 1.5])
ax[0,0].set_ylim([-5, 1.5])
ax[1,2].set_ylim([-5, 1.5])
ax[1,1].set_ylim([-5, 1.5])
ax[1,0].set_ylim([-5, 1.5])
ax[2,2].set_ylim([-5, 1.5])
ax[2,1].set_ylim([-5, 1.5])
ax[2,0].set_ylim([-5, 1.5])
ax[3,2].set_ylim([-5, 1.5])
ax[3,1].set_ylim([-5, 1.5])
ax[3,0].set_ylim([-5, 1.5])
ax[4,2].set_ylim([-5, 1.5])
ax[4,1].set_ylim([-5, 1.5])
ax[4,0].set_ylim([-5, 1.5])
ax[5,2].set_ylim([-5, 1.5])
ax[5,1].set_ylim([-5, 1.5])
ax[5,0].set_ylim([-5, 1.5])

ax[0,1].get_yaxis().set_visible(False)
ax[0,2].get_yaxis().set_visible(False)
ax[1,1].get_yaxis().set_visible(False)
ax[1,2].get_yaxis().set_visible(False)
ax[2,1].get_yaxis().set_visible(False)
ax[2,2].get_yaxis().set_visible(False)
ax[3,1].get_yaxis().set_visible(False)
ax[3,2].get_yaxis().set_visible(False)
ax[4,1].get_yaxis().set_visible(False)
ax[4,2].get_yaxis().set_visible(False)
ax[5,1].get_yaxis().set_visible(False)
ax[5,2].get_yaxis().set_visible(False)

ax[5,1].set_xlabel('Time (ns)')
ax[2,0].set_ylabel('$\Delta$Angels ($\degree$)')

leg=ax[2,1].legend(prop={"size":10})
leg2=ax[3,1].legend(prop={"size":10})

ax[0,0].text(20, 2, 'AMBER19SB')
ax[0,1].text(20, 2, 'CHARMM36m')
ax[0,2].text(20, 2, 'OPLS-AA/M')

ax[0,2].text(240, -1.9, 'VQIVYK', rotation='90')
ax[1,2].text(120, -1.9, 'GGVVIA', rotation='90')
ax[2,2].text(120, -1.9, 'LYQLEN', rotation='90')
ax[3,2].text(120, -1.9, 'VEALYL', rotation='90')
ax[4,2].text(120, -2.4, 'NNFGAIL', rotation='90')
ax[5,2].text(120, -2.4, 'SSTNVG', rotation='90')

plt.subplots_adjust(wspace=0)
plt.savefig('angles2.pdf', dpi=100, bbox_inches='tight')

#VQIVYK, GGVVIA, LYQLEN, VEALYL, NNFGAIL, and SSTNVG
